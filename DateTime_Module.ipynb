# %% [markdown]
# # DateTime Module

# %%
#Import Datetime Module

import datetime

# %%
#today date
datetime.date.today()
# Out:
# datetime.date(2021, 2, 21)

# %%
# Create Date
# The datetime() class requires three parameters to create a date: year, month, day
date1 = datetime.date(1996, 10, 26)
print(date1)
# Out:
# 1996-10-26

# %%
#create date2
date2 = datetime.date(2021, 2, 21)
print(date2)
# Out:
# 2021-02-21

# %%
#Difference of dates
print(date2 - date1)
# Out:
# 8884 days, 0:00:00

# %%
#Comparision of dates
print(date1 < date2)
print(date1 > date2)
print(date1 == date2)
# Out:
# True
# False
# False

# %%
x = datetime.datetime.now()
print(x)

#to get year
print(x.year)
# Out:
# 2021-02-21 07:49:10.055325
# 2021

# %%
# to get the day only
print(x.strftime("%A"))
# Out:
# Sunday

# %%
# To get the month only
print(x.strftime("%B"))
# Out:
# February

# %%
# To get full day, month and year
print(x.strftime("%A-%B-%Y"))
# Out:
# Sunday-February-2021

# %% [markdown]
# %a	Weekday, short version	Wed
# %A	Weekday, full version	Wednesday
# %w	Weekday as a number 0-6, 0 is Sunday	3
# %d	Day of month 01-31	31
# %b	Month name, short version	Dec
# %B	Month name, full version	December
# %m	Month as a number 01-12	12
# %y	Year, short version, without century	18
# %Y	Year, full version	2018
# %H	Hour 00-23	17
# %I	Hour 00-12	05
# %p	AM/PM	PM
# %M	Minute 00-59	41
# %S	Second 00-59	08
# %f	Microsecond 000000-999999	548513
# %z	UTC offset	+0100
# %Z	Timezone	CST
# %j	Day number of year 001-366	365
# %U	Week number of year, Sunday as the first day of week, 00-53	52
# %W	Week number of year, Monday as the first day of week, 00-53	52
# %c	Local version of date and time	Mon Dec 31 17:41:00 2018
# %x	Local version of date	12/31/18
# %X	Local version of time	17:41:00
# %%	A % character	%
# %G	ISO 8601 year	2018
# %u	ISO 8601 weekday (1-7)	1
# %V	ISO 8601 weeknumber (01-53)	01
